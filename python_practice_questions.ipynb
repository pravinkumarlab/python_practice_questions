# %% [markdown]
# <a href="https://colab.research.google.com/github/pravinkumarlab/python_practice_questions/blob/main/python_practice_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Odd or Even Sum**
#
# Problem Statement:
# Given 2 numbers N and M add both the numbers and check whether the sum is odd or even.

# %%
N,M = map(int, input().split())
print("even" if (N+M)%2==0 else "odd")
# Out:
# 6 6
# even

# %% [markdown]
# # **2. Prime Number Check**
#
# Problem Statement:
# Given a number N, check whether it is prime or not. Print 'yes' if it is prime else print 'no'.

# %%
N = int(input())
if N>1:
  for i in range(2,int(N**0.5)+1):
    if N % i == 0:
      print("no")
      break
  else:
    print("yes")
else:
  print("no")
# Out:
# 97
# yes

# %% [markdown]
# # **3. Check Divisibility by 7**
# Problem Statement:
# Given a number N, print yes if the number is a multiple of 7 else print no.

# %% [markdown]
# ## **4. Pyramid Pattern**
#
# **Problem Statement:**
# Given an integer N, print a pyramid pattern of asterisks.

# %%
def pyramid():
    n = int(input())
    for i in range(1, n + 1):
        spaces = "  " * (n - i)
        stars = " ".join(["*"] * (2*i - 1))
        print(spaces + stars)
pyramid()
# Out:
# 5
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *
